# %%
import pandas as pd
# !pip install chardet
# Out:
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (5.2.0)

# %%
import chardet

# %%
with open("/content/drive/MyDrive/DA a Long/Music_shop_v1.csv", "rb") as f:
    encoding = chardet.detect(f.read())["encoding"]

# %%
df = pd.read_csv("/content/drive/MyDrive/DA a Long/Music_shop_v1.csv", encoding=encoding)

# %%
df.head()
# Out:
#                        ID                           Name  Energy  Loudness  \
# 0  62E8JJRtwOwU85uup9C5Ox                 ParecenViernes   0.863    -3.575
# 1  3yEtuhGR8jOtusa29jWrhG  TuAmorMeHaceBien-SalsaVersion   0.658    -6.496
# 2  3WXfQDsASfXrSojk9WB3aR          EnBarranquillaMeQuedo   0.700    -9.213
# 3  6bum69IXoiGcZCb83ZtfGA                   MeTengoQueIr   0.799    -3.275
# 4  23Vb5teQKNSNvPgUjLtI8j                        LaMurga   0.771    -7.530
#
#    Speechiness  Instrumentalness            Type  time_signature
# 0       0.0352          0.000015  audio_features               4
# 1       0.0359          0.000046  audio_features               4
# 2       0.0552          0.000232  audio_features               4
# 3       0.0375          0.000000  audio_features               4
# 4       0.0436          0.002650  audio_features               4

# %%
df.shape
# Out:
# (2980, 8)

# %%
df.nunique()
# Out:
# ID                  2686
# Name                2562
# Energy              1011
# Loudness            2461
# Speechiness          854
# Instrumentalness    1302
# Type                   1
# time_signature         5
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2980 entries, 0 to 2979
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ID                2980 non-null   object
#  1   Name              2980 non-null   object
#  2   Energy            2979 non-null   float64
#  3   Loudness          2979 non-null   float64
#  4   Speechiness       2980 non-null   float64
#  5   Instrumentalness  2979 non-null   float64
#  6   Type              2980 non-null   object
#  7   time_signature    2980 non-null   int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 186.4+ KB

# %%
df.describe()
# Out:
#             Energy     Loudness  Speechiness  Instrumentalness  time_signature
# count  2979.000000  2979.000000  2980.000000       2979.000000     2980.000000
# mean      0.536668   -10.891324     0.100892          0.360294        3.886577
# std       0.282891     6.751657     0.174626          0.410324        0.492189
# min       0.000376   -39.967000     0.000000          0.000000        0.000000
# 25%       0.277000   -14.626500     0.037500          0.000007        4.000000
# 50%       0.603000    -8.751000     0.045900          0.024400        4.000000
# 75%       0.774000    -5.816000     0.074000          0.851000        4.000000
# max       1.825000     9.305000     3.073500          1.020900        5.000000

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Energy', 'Loudness', 'Speechiness', 'Instrumentalness',
#        'Type', 'time_signature'],
#       dtype='object')

# %%
df[['ID']].value_counts()
# Out:
# ID
# 7nDIflSHQXzaa8zupxwv3U    4
# 1P4XzKG2bldGbhg6EO1N23    4
# 2iuf8q0JzFh6oJdFYXsx1v    4
# 236qXqcmitHCZ3SHoGZN8g    3
# 48bFgWuYofpZqmIxC82R8V    3
#                          ..
# 2mSlx4jdNQJ8BK10ntyt6l    1
# 2mdxJLJHzFmiiYdTZ8JcyH    1
# 2mjcSFZm71YuqETWajjWFj    1
# 2moGHNaU8a4j1iowyOiYnF    1
# 3rJ8Q7M9HGu4gczNY4osfZ    1
# Name: count, Length: 2686, dtype: int64

# %%
# Assuming 'df' is your original DataFrame and 'ID' is the column with the duplicate values.
df= df.drop_duplicates(subset='ID', keep='first')

# %%
df.isnull().sum()
# Out:
# ID                  0
# Name                0
# Energy              1
# Loudness            1
# Speechiness         0
# Instrumentalness    1
# Type                0
# time_signature      0
# dtype: int64

# %%
df['Name'].value_counts()
# Out:
# Name
# Spain            4
# CasiTeEnvidio    4
# Lloraras         3
# UnaAventura      3
# Micaela          3
#                 ..
# Exodus36         1
# Exodus37         1
# Exodus38         1
# Exodus39         1
# LoveLetter       1
# Name: count, Length: 2562, dtype: int64

# %%
missing_data_rows = df[df.isnull().any(axis=1)].dropna(axis=0, how='any')
df = df.dropna()
df
# Out:
#                           ID                           Name  Energy  Loudness  \
# 0     62E8JJRtwOwU85uup9C5Ox                 ParecenViernes   0.863    -3.575
# 1     3yEtuhGR8jOtusa29jWrhG  TuAmorMeHaceBien-SalsaVersion   0.658    -6.496
# 2     3WXfQDsASfXrSojk9WB3aR          EnBarranquillaMeQuedo   0.700    -9.213
# 3     6bum69IXoiGcZCb83ZtfGA                   MeTengoQueIr   0.799    -3.275
# 4     23Vb5teQKNSNvPgUjLtI8j                        LaMurga   0.771    -7.530
# ...                      ...                            ...     ...       ...
# 2975  4zMmqb0pYwX6b0qc0slCoT                      OnlyChild   0.365    -7.024
# 2976  5s4mj6ILv52pz9OM9yRgaR                      NeverBeen   0.580    -7.063
# 2977  2uqLbKYdXc4F25g4l1FWye                           Back   0.719    -6.402
# 2978  3o7y5ysLlP1aNUR6QMI3F4                       Polaroid   0.650    -6.715
# 2979  380v3gb384xxUt8A3C8aqt                     LoveLetter   0.676    -6.869
#
#       Speechiness  Instrumentalness            Type  time_signature
# 0          0.0352          0.000015  audio_features               4
# 1          0.0359          0.000046  audio_features               4
# 2          0.0552          0.000232  audio_features               4
# 3          0.0375          0.000000  audio_features               4
# 4          0.0436          0.002650  audio_features               4
# ...           ...               ...             ...             ...
# 2975       0.0412          0.000004  audio_features               4
# 2976       0.0357          0.004540  audio_features               4
# 2977       0.0309          0.000000  audio_features               4
# 2978       0.0922          0.000000  audio_features               4
# 2979       0.0317          0.000000  audio_features               4
#
# [2683 rows x 8 columns]

# %%
df1 = df[['Loudness','Speechiness', 'Instrumentalness']]
df1
# Out:
#       Loudness  Speechiness  Instrumentalness
# 0       -3.575       0.0352          0.000015
# 1       -6.496       0.0359          0.000046
# 2       -9.213       0.0552          0.000232
# 3       -3.275       0.0375          0.000000
# 4       -7.530       0.0436          0.002650
# ...        ...          ...               ...
# 2975    -7.024       0.0412          0.000004
# 2976    -7.063       0.0357          0.004540
# 2977    -6.402       0.0309          0.000000
# 2978    -6.715       0.0922          0.000000
# 2979    -6.869       0.0317          0.000000
#
# [2683 rows x 3 columns]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X = scaler.fit_transform(df1.values)

# %%
X
# Out:
# array([[ 1.06815305, -0.40486252, -0.83713197],
#        [ 0.61405706, -0.40082983, -0.8370562 ],
#        [ 0.19167473, -0.28964297, -0.83659363],
#        ...,
#        [ 0.62867022, -0.42963472, -0.83716998],
#        [ 0.58001152, -0.0764868 , -0.83716998],
#        [ 0.55607083, -0.42502594, -0.83716998]])

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=3, random_state=42)
model.fit(X)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3, random_state=42)

# %%
y = model.predict(X)

# %%
y
# Out:
# array([1, 1, 1, ..., 1, 1, 1], dtype=int32)

# %%
df1['Cluster_ID'] = y
# Out:
# <ipython-input-24-5103b7d3aa40>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Cluster_ID'] = y

# %%
df1
# Out:
#       Loudness  Speechiness  Instrumentalness  Cluster_ID
# 0       -3.575       0.0352          0.000015           1
# 1       -6.496       0.0359          0.000046           1
# 2       -9.213       0.0552          0.000232           1
# 3       -3.275       0.0375          0.000000           1
# 4       -7.530       0.0436          0.002650           1
# ...        ...          ...               ...         ...
# 2975    -7.024       0.0412          0.000004           1
# 2976    -7.063       0.0357          0.004540           1
# 2977    -6.402       0.0309          0.000000           1
# 2978    -6.715       0.0922          0.000000           1
# 2979    -6.869       0.0317          0.000000           1
#
# [2683 rows x 4 columns]

# %%
df1['Cluster_ID'].value_counts()
# Out:
# Cluster_ID
# 1    1574
# 2    1001
# 0     108
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
cluster_gr = sns.pairplot(df1, hue='Cluster_ID')
plt.show()

# %% [markdown]
# Cluster 0:
# loudness: medium
# speechiness:highest
# instrumentalness: varying but mostly low
#
# Cluster 1:
# loudness: highest
# speechiness: low
# instrumentalness: varying but mostly low
#
# Cluster 2:
# loudness: varying from low to high
# speechiness: low
# instrumentalness: varying but mostly high

# %%
clusters = []
inertia_vals = []

for k in range(2,10,1):
  model = KMeans(n_clusters=k, random_state=42)
  model.fit(X)
  clusters.append(model)
  inertia_vals.append(model.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
plt.plot(range(2,10,1), inertia_vals, marker = "*")
plt.show()

# %%
from sklearn.metrics import silhouette_score
print(clusters[0])
print("Silhouette Score for k=2: ", silhouette_score(X, clusters[0].predict(X)))

print(clusters[1])
print("Silhouette Score for k=3: ", silhouette_score(X, clusters[1].predict(X)))

print(clusters[2])
print("Silhouette Score for k=4: ", silhouette_score(X, clusters[2].predict(X)))
# Out:
# KMeans(n_clusters=2, random_state=42)
# Silhouette Score for k=2:  0.5177807296427909
# KMeans(n_clusters=3, random_state=42)
# Silhouette Score for k=3:  0.5880651102287904
# KMeans(n_clusters=4, random_state=42)
# Silhouette Score for k=4:  0.5799028356764897

# %%
df1
# Out:
#       Loudness  Speechiness  Instrumentalness  Cluster_ID
# 0       -3.575       0.0352          0.000015           1
# 1       -6.496       0.0359          0.000046           1
# 2       -9.213       0.0552          0.000232           1
# 3       -3.275       0.0375          0.000000           1
# 4       -7.530       0.0436          0.002650           1
# ...        ...          ...               ...         ...
# 2975    -7.024       0.0412          0.000004           1
# 2976    -7.063       0.0357          0.004540           1
# 2977    -6.402       0.0309          0.000000           1
# 2978    -6.715       0.0922          0.000000           1
# 2979    -6.869       0.0317          0.000000           1
#
# [2683 rows x 4 columns]

# %%
# prompt: Using dataframe df1:

# Create a scatter plot with Loudness on the x-axis and Speechiness on the y-axis, colored by Cluster_ID
import altair as alt
chart = alt.Chart(df1).mark_point().encode(
    x=alt.X('Loudness', title='Loudness'),
    y=alt.Y('Speechiness', title='Speechiness'),
    color=alt.Color('Cluster_ID:N', legend=alt.Legend(title='Cluster ID'))
).interactive()
chart
# Out:
# alt.Chart(...)
